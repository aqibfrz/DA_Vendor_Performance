# %%
from helper_functions import print_llm_response
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from helper_functions import print_llm_response
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\helper_functions.py:3
#       1 ''' This file is a package contains helper functions for opencv and imgs '''
# ----> 3 import cv2
#       4 import numpy as np
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'cv2'
